# %% [markdown]
# # Data Extraction

# %% [markdown]
# ### Import Essential Libraries
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset from Kaggle : **"CO2 Emission by Vehicles"**
# Source: https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles/data
#
# The dataset is `CO2 Emissions_Canada.csv`; hence we use the `read_csv` function from Pandas.

# %%
df = pd.read_csv('CO2 Emissions_Canada.csv')
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %% [markdown]
# ### About Dataset
# **Make**: Company of the vehicle
# **Model**: Car Model
# **Vehicle Class**: Class of vehicle depending on their utility, capacity and weight
# **Engine Size(L)**: Size of engine used in Litre
# **Cylinders**: Number of cylinders (engine’s power unit where fuel combustion takes place to generate power that moves a car.)
# **Transmission**: Transmission type with number of gears (3-10)
# - A = Automatic
# - AM = Automated manual
# - AS = Automatic with select shift
# - AV = Continuously variable
# - M = Manual
#
# **Fuel Type**: Type of fuel used
# - X = Regular gasoline
# - Z = Premium gasoline
# - D = Diesel
# - E = Ethanol (E85)
# - N = Natural gas
#
# **Fuel Consumption City (L/100 km)**: Fuel consumption in city roads in litres per 100 kilometres
# **Fuel Consumption Hwy (L/100 km)**: Fuel consumption in highways in litres per 100 kilometres
# **Fuel Consumption Comb (L/100 km)**: The combined fuel consumption (55% city, 45% highway) in litres per 100 kilometres
# **Fuel Consumption Comb (mpg)**: The combined fuel consumption (55% city, 45% highway) in mile per gallon
# **CO2 Emissions(g/km)**: The tailpipe emissions of carbon dioxide in grams per kilometre for combined city and highway driving

# %%
print("Data type : ", type(df))
print("Data dims : ", df.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (7385, 12)

# %%
# Information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
# Unique value of each column
df.nunique()
# Out:
# Make                                  42
# Model                               2053
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              5
# Fuel Consumption City (L/100 km)     211
# Fuel Consumption Hwy (L/100 km)      143
# Fuel Consumption Comb (L/100 km)     181
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  331
# dtype: int64

# %% [markdown]
# ### Data types
#
# **Make**: Categorical
# **Model**: Categorical
# **Vehicle Class**: Categorical
# **Engine Size(L)**: Numerical
# **Cylinders**: Numerical
# **Transmission**: Categorical
# **Fuel Type**: Categorical
# **Fuel Consumption City (L/100 km)**: Numerical
# **Fuel Consumption Hwy (L/100 km)**: Numerical
# **Fuel Consumption Comb (L/100 km)**: Numerical
# **Fuel Consumption Comb (mpg)**: Numerical
# **CO2 Emissions(g/km)**: Numerical

# %% [markdown]
# # Data Cleaning

# %%
# Create a copy of the dataset
df_clean = df.copy()

# %% [markdown]
# ### Check for Missing Data

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# There are no missing data in any of the columns.

# %% [markdown]
# ### Check for Duplicated Data

# %%
print("Number of duplicated data:", df.duplicated().sum())
# Out:
# Number of duplicated data: 1103

# %%
# Extract and Display the rows that are duplicated
dfDuplicated = df[df.duplicated() == True]
dfDuplicated.head()
# Out:
#               Make       Model Vehicle Class  Engine Size(L)  Cylinders  \
# 1075         ACURA     RDX AWD   SUV - SMALL             3.5          6
# 1076         ACURA         RLX      MID-SIZE             3.5          6
# 1081    ALFA ROMEO          4C    TWO-SEATER             1.8          4
# 1082  ASTON MARTIN         DB9   MINICOMPACT             5.9         12
# 1084  ASTON MARTIN  V8 VANTAGE    TWO-SEATER             4.7          8
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 1075          AS6         Z                              12.1
# 1076          AS6         Z                              11.9
# 1081          AM6         Z                               9.7
# 1082           A6         Z                              18.0
# 1084          AM7         Z                              17.4
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1075                              8.7                              10.6
# 1076                              7.7                              10.0
# 1081                              6.9                               8.4
# 1082                             12.6                              15.6
# 1084                             11.3                              14.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1075                           27                  244
# 1076                           28                  230
# 1081                           34                  193
# 1082                           18                  359
# 1084                           19                  338

# %%
# Drop the duplicated rows
df_clean = df.drop_duplicates()
print("Data dims : ", df_clean.shape)
# Out:
# Data dims :  (6282, 12)

# %% [markdown]
# ### Create a new column for Number of Gears

# %%
# Create a copy of the dataset
df_clean2 = df_clean.copy()

# Extract number of gears from 'Transmission' column
df_clean2['Number of Gears'] = df_clean2['Transmission'].str.extract(r'(\d+)', expand=False)

# Remove number of gears from 'Transmission' column
df_clean2['Transmission'] = df_clean2['Transmission'].str.replace(r'\d+', '', regex=True)

df_clean2.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4           AS
# 1  ACURA         ILX       COMPACT             2.4          4            M
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4           AV
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6           AS
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6           AS
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km) Number of Gears
# 0                           33                  196               5
# 1                           29                  221               6
# 2                           48                  136               7
# 3                           25                  255               6
# 4                           27                  244               6

# %%
# Check for missing values in number of gears column
print("Number of rows with missing values:",df_clean2["Number of Gears"].isnull().sum())
# Out:
# Number of rows with missing values: 241

# %%
# Extract rows with null values in the "Number of Gears" column
rows_with_null_gears = df_clean2[df_clean2["Number of Gears"].isnull()]

# Display the extracted rows
rows_with_null_gears.head()
# Out:
#           Make          Model Vehicle Class  Engine Size(L)  Cylinders  \
# 259  CHEVROLET          SPARK    SUBCOMPACT             1.2          4
# 342       FORD   C-MAX HYBRID     FULL-SIZE             2.0          4
# 415       FORD  FUSION HYBRID      MID-SIZE             2.0          4
# 481      HONDA         ACCORD      MID-SIZE             2.4          4
# 487      HONDA  ACCORD HYBRID      MID-SIZE             2.0          4
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 259           AV         X                               7.7
# 342           AV         X                               5.6
# 415           AV         X                               5.3
# 481           AV         X                               9.0
# 487           AV         X                               4.7
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 259                              6.0                               6.9
# 342                              6.4                               6.0
# 415                              5.7                               5.5
# 481                              6.6                               7.9
# 487                              4.9                               4.8
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km) Number of Gears
# 259                           41                  159             NaN
# 342                           47                  138             NaN
# 415                           51                  126             NaN
# 481                           36                  182             NaN
# 487                           59                  110             NaN

# %% [markdown]
# The percentage of missing values in number of gears column is 3.84% (241/6282) which is small and may not signficiantly impact out analysis. Hence, we have chosen to drop these rows to simplify data analysis and processing.

# %%
# Drop the rows with null values in the "Number of Gears" column
df_clean2.dropna(subset=["Number of Gears"], inplace=True)
print("Data dims : ", df_clean2.shape)
# Out:
# Data dims :  (6041, 13)

# %% [markdown]
# ### Drop Unnecessary Columns
# Fuel Consumption Comb (L/100 km) and Fuel Consumption Comb (mpg) measures the same quantity — fuel consumption - but in different units.
# We will use Fuel Consumption Comb (L/100 km) only for our investigation.

# %%
# Create a copy of the dataset
df_clean3 = df_clean2.copy()

# Drop 'Fuel Consumption Comb (mpg)' column
df_clean3.drop(columns=['Fuel Consumption Comb (mpg)'], inplace=True)
df_clean3.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4           AS
# 1  ACURA         ILX       COMPACT             2.4          4            M
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4           AV
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6           AS
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6           AS
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    CO2 Emissions(g/km) Number of Gears
# 0                  196               5
# 1                  221               6
# 2                  136               7
# 3                  255               6
# 4                  244               6

# %%
df_clean2.to_csv('CO2 Emissions_Canada_cleaned.csv')
